# %% [markdown]
# # starter4
#
# > helloworld starter example migrated to htmx v4

# %%
from fasthtml.common import *
from fasthtml.jupyter import *
from hx4_patch.core import *

# %%
from random import random
app,rt = fast_app(htmx=False, htmx4=True)

@rt
def index():
    return Titled(
        'Hello',
        Div(P('click'), post=rnd)
    )

@rt
def rnd(): return P(random())

srv = JupyUvi(app)

# %%
srv.stop()
